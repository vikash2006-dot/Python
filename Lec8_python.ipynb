# %% [markdown]
# <a href="https://colab.research.google.com/github/vikash2006-dot/Python/blob/main/Lec8_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1=pd.DataFrame({
    'id':[1,2,3,4],
    'name':['Raja','Rani','Rahul','Rhea'],
    'age':[25,30,35,40]
})

df2=pd.DataFrame({
    'id':[3,4,5,6],
    'name':['Rahul','Rhea','Ravi','Reema'],
    'age':[35,40,45,50]
})
# inner joint gives the common data of both tables
df3=pd.merge(df1,df2, on='id' , how='inner')
df3.rename(columns={'name_x':'name1','name_y':'name2'},inplace=True)
display(df3)
# Out:
#    id  name1  age_x  name2  age_y
# 0   3  Rahul     35  Rahul     35
# 1   4   Rhea     40   Rhea     40

# %%
df3=pd.merge(df1,df2, on='id' , how='left')
display(df3)

# left joint gives the whole data of left table and put NaN if table 2 data is not present
# Out:
#    id name_x  age_x name_y  age_y
# 0   1   Raja     25    NaN    NaN
# 1   2   Rani     30    NaN    NaN
# 2   3  Rahul     35  Rahul   35.0
# 3   4   Rhea     40   Rhea   40.0

# %%
df3=pd.merge(df1,df2, on='id' , how='right')
display(df3)
# right joint gives the whole data of right table and put NaN if table 1 data is not present
# Out:
#    id name_x  age_x name_y  age_y
# 0   3  Rahul   35.0  Rahul     35
# 1   4   Rhea   40.0   Rhea     40
# 2   5    NaN    NaN   Ravi     45
# 3   6    NaN    NaN  Reema     50

# %%
df3=pd.merge(df1,df2, on='id' , how='outer')
display(df3)

# outer joint gives all values of both table and put NaN if any value does not exist
# Out:
#    id name_x  age_x name_y  age_y
# 0   1   Raja   25.0    NaN    NaN
# 1   2   Rani   30.0    NaN    NaN
# 2   3  Rahul   35.0  Rahul   35.0
# 3   4   Rhea   40.0   Rhea   40.0
# 4   5    NaN    NaN   Ravi   45.0
# 5   6    NaN    NaN  Reema   50.0

# %%
df3=pd.merge(df1,df2, how='cross')
display(df3)

# A cross join in pandas creates a Cartesian product of two DataFrames, meaning it combines
# every row from the first DataFrame with every row from the second DataFrame
# Out:
#     id_x name_x  age_x  id_y name_y  age_y
# 0      1   Raja     25     3  Rahul     35
# 1      1   Raja     25     4   Rhea     40
# 2      1   Raja     25     5   Ravi     45
# 3      1   Raja     25     6  Reema     50
# 4      2   Rani     30     3  Rahul     35
# 5      2   Rani     30     4   Rhea     40
# 6      2   Rani     30     5   Ravi     45
# 7      2   Rani     30     6  Reema     50
# 8      3  Rahul     35     3  Rahul     35
# 9      3  Rahul     35     4   Rhea     40
# 10     3  Rahul     35     5   Ravi     45
# 11     3  Rahul     35     6  Reema     50
# 12     4   Rhea     40     3  Rahul     35
# 13     4   Rhea     40     4   Rhea     40
# 14     4   Rhea     40     5   Ravi     45
# 15     4   Rhea     40     6  Reema     50

# %%
df3=pd.concat([df1,df2])
display(df3)
# Out:
#    id   name  age
# 0   1   Raja   25
# 1   2   Rani   30
# 2   3  Rahul   35
# 3   4   Rhea   40
# 0   3  Rahul   35
# 1   4   Rhea   40
# 2   5   Ravi   45
# 3   6  Reema   50

# %%
# converts the string date type into standard date type
pd.to_datetime()

# %%
import pandas as pd
df=pd.read_csv('student_data.csv')

df.pivot_table(columns='placement_status',index='sleep_hours',values='exam_score',aggfunc='mean')

df.pivot_table(columns='study_hours',index='sleep_hours',values='assignments_completed',aggfunc='mean')
# Out:
# study_hours         1          2          3          4          5          6   \
# sleep_hours
# 4             9.980392  10.283784  10.166667   9.529801  10.187050  10.530612
# 5            10.231707   9.837838  10.051948   9.706667   9.679487  10.604651
# 6            10.566265  10.417808  10.229299   9.694805  10.066667  10.131737
# 7            11.026846   9.166667   9.440252  10.007143   9.888889   9.606250
# 8             9.303448   8.741935   9.807692  10.204545   9.843373  10.105960
# 9            10.245283   9.646667   9.968944   9.582822  10.308725   9.744681
#
# study_hours         7          8          9          10         11
# sleep_hours
# 4             9.836158  10.486111   9.950000   9.114458   9.662420
# 5            11.151515  10.118519  10.616279   9.886228   9.863946
# 6             9.934307  10.601399   9.868966   9.375000   9.291045
# 7            10.750000   8.380368  11.130719  10.506024   9.741007
# ...

# %%
# Homework
# 1327 , 511, 586, 1050, 175, 181, 182, 184, 185, 1179
