# %% [markdown]
# <a href="https://colab.research.google.com/github/vikash2006-dot/Python/blob/main/Lec3_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def addition(a,b):
  return a+b
addition(3,4)
# Out:
# 7

# %%
#lamda function
x=lambda a,b : b*a
print (x(2,3))
# Out:
# 6

# %%
#string functions
st=""
print(len(st))
# upper
s="hello"
s1=s.upper()
# lower
print(s1)
print(s1.lower())
# title
print(s1.title())
# capitalize()
S2="hello world"
print(S2.capitalize())

#strip function
# remove extra space from the front and end of the string
first = '   Anmol '
last = '   kuntal '
x= first.strip()
y= last.strip()
print(x+' '+y)
# Out:
# 0
# HELLO
# hello
# Hello
# Hello world
# Anmol kuntal

# %%
a = " today "
b="  weather  "
c="is GooD"
a1=a.strip()
b1=b.strip()
s=a1+' '+b1+' '+c
x=s.lower()
y=x.title()
print(y)

# replace()
print(y.replace("Good","Bad"))

# find()
# find returns -1 if word does not present
print(y.find("Good"))
# Out:
# Today Weather Is Good
# Today Weather Is Bad
# 17

# %%
# dictionary
dct = {
    "name":["Ramesh","Suresh","kamal"],
    "age":23,
    "class":12,
    "Roll no.":25
}
print(dct["name"])

dct["id"] = 10031
print(dct)

# delete
del dct["name"]
print(dct)
# Out:
# ['Ramesh', 'Suresh', 'kamal']
# {'name': ['Ramesh', 'Suresh', 'kamal'], 'age': 23, 'class': 12, 'Roll no.': 25, 'id': 10031}
# {'age': 23, 'class': 12, 'Roll no.': 25, 'id': 10031}
